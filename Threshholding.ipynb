# %%
import numpy as np
import torch
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
batch_size = 64

train_root = r'C:\Users\Dhruv\Documents\Github\EE541\EE541_project\Preprocessing\symlink_Data\asl_alphabet_train'
train_set = torchvision.datasets.ImageFolder(train_root, transform = transforms.Compose([transforms.ToTensor()]))
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)

# %%
print(train_set)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 18000
#     Root location: C:\Users\Dhruv\Documents\Github\EE541\EE541_project\Preprocessing\symlink_Data\asl_alphabet_train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )

# %%
random_image = train_set[4000][0]
random_image_label = train_set[4000][1]

# Print the Image using Matplotlib
plt.imshow(random_image.permute(1,2,0))
print("The label of the image is:", random_image_label)
# Out:
# The label of the image is: 1

# %%
import cv2

# %%
random_image = train_set[6000][0]
max_value = 255
max_binary_value = 255

src = np.array(random_image.permute(1,2,0))*max_value
src_gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

threshold_type = 4
threshold_value = 40
_, dst = cv2.threshold(src_gray, threshold_value, max_binary_value, threshold_type )
plt.imshow(dst,cmap='gray', vmin=0, vmax=255)
